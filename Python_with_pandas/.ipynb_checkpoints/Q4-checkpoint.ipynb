# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Load the data in a dataframe
df = pd.read_csv('ie_cpi_data.csv')

# %%
# seaborn pait plot showing grid of Axes such that each numeric variable in data will by shared across the y-axes across a 
# single row and the x-axes across a single column.
sns.pairplot(df)
