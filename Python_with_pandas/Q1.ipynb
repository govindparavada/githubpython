# %%
import pandas as pd

# %%
#Load the data in a dataframe
df = pd.read_csv('ie_cpi_data.csv')

# %%
#First 10 lines from data set
df.head(10)
# Out:
#                             Statistic Label  Year     Date  Alcohol  \
# 0  Consumer Price Index (Base Dec 2016=100)  2002  2002-10     81.1
# 1  Consumer Price Index (Base Dec 2016=100)  2002  2002-11     81.1
# 2  Consumer Price Index (Base Dec 2016=100)  2002  2002-12     82.2
# 3  Consumer Price Index (Base Dec 2016=100)  2003  2003-01     84.1
# 4  Consumer Price Index (Base Dec 2016=100)  2003  2003-02     84.3
# 5  Consumer Price Index (Base Dec 2016=100)  2003  2003-03     85.1
# 6  Consumer Price Index (Base Dec 2016=100)  2003  2003-04     85.9
# 7  Consumer Price Index (Base Dec 2016=100)  2003  2003-05     86.1
# 8  Consumer Price Index (Base Dec 2016=100)  2003  2003-06     86.3
# 9  Consumer Price Index (Base Dec 2016=100)  2003  2003-07     86.5
#
#    Energy Products  Goods  Mortgage Interest  Services  Tobacco  \
# 0             60.5  107.2               90.6      68.3     46.4
# 1             60.1  107.2               91.5      68.4     46.5
# ...

# %%
#Last 20 lines from data set
df.tail(20)
# Out:
#                               Statistic Label  Year     Date  Alcohol  \
# 221  Consumer Price Index (Base Dec 2016=100)  2021  2021-03    107.1
# 222  Consumer Price Index (Base Dec 2016=100)  2021  2021-04    107.8
# 223  Consumer Price Index (Base Dec 2016=100)  2021  2021-05    107.5
# 224  Consumer Price Index (Base Dec 2016=100)  2021  2021-06    107.0
# 225  Consumer Price Index (Base Dec 2016=100)  2021  2021-07    107.3
# 226  Consumer Price Index (Base Dec 2016=100)  2021  2021-08    107.5
# 227  Consumer Price Index (Base Dec 2016=100)  2021  2021-09    108.4
# 228  Consumer Price Index (Base Dec 2016=100)  2021  2021-10    107.5
# 229  Consumer Price Index (Base Dec 2016=100)  2021  2021-11    106.2
# 230  Consumer Price Index (Base Dec 2016=100)  2021  2021-12    104.5
# 231  Consumer Price Index (Base Dec 2016=100)  2022  2022-01    111.4
# 232  Consumer Price Index (Base Dec 2016=100)  2022  2022-02    110.5
# ...

# %%
## summary statistics of data set
print(df.describe())
# Out:
#               Year     Alcohol  Energy Products       Goods  \
# count   241.000000  241.000000       241.000000  241.000000
# mean   2012.290456   97.670124        98.581743  106.252282
# std       5.816524    6.881722        21.249710    6.249920
# min    2002.000000   81.100000        59.900000   93.100000
# 25%    2007.000000   93.300000        85.400000   99.800000
# 50%    2012.000000   98.800000       100.800000  108.600000
# 75%    2017.000000  102.300000       110.600000  110.800000
# max    2022.000000  114.200000       189.200000  118.300000
#
#        Mortgage Interest    Services     Tobacco  Utilities and Local Charges
# count         241.000000  241.000000  241.000000                    241.00000
# mean          119.494606   92.697510   84.675934                     93.16805
# std            30.308064   12.433054   24.748582                     21.18159
# min            75.500000   68.300000   46.400000                     23.00000
# ...

# %%
#columns of the data set
print(df.columns)
# Out:
# Index(['Statistic Label', 'Year', 'Date', 'Alcohol', 'Energy Products',
#        'Goods', 'Mortgage Interest', 'Services', 'Tobacco',
#        'Utilities and Local Charges'],
#       dtype='object')

# %%
# summary statistics of Energy Products
print(df["Energy Products"].describe(include="all"))
# Out:
# count    241.000000
# mean      98.581743
# std       21.249710
# min       59.900000
# 25%       85.400000
# 50%      100.800000
# 75%      110.600000
# max      189.200000
# Name: Energy Products, dtype: float64
